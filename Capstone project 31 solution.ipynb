# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DataCoSupplyChainDataset (1).csv',encoding='ISO-8859-1')

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df.drop(['Customer Email','Customer Password','Product Image'],axis=1,inplace=True)

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# Longitude                             0
# Market                                0
# ...

# %%
df.drop(['Customer Lname','Order Zipcode','Product Description','Customer Zipcode'],axis=1,inplace=True)

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
pd.crosstab(df['Customer City'],df['Order Status'])[['PENDING']]
# Out:
# Order Status   PENDING
# Customer City
# Aguadilla           11
# Alameda             13
# Albany               8
# Albuquerque         69
# Algonquin            5
# ...                ...
# Yonkers             24
# York                20
# Ypsilanti           14
# Yuma                 7
# Zanesville          21
#
# [563 rows x 1 columns]

# %%
x = df[df['Order Country']=='India']

# %%
x
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 13         DEBIT                         2                              1
# 14      TRANSFER                         2                              1
# 15         DEBIT                         2                              1
# ...          ...                       ...                            ...
# 180488   PAYMENT                         2                              4
# 180490  TRANSFER                         4                              4
# 180493     DEBIT                         2                              4
# 180494     DEBIT                         2                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
pd.crosstab(x['Order City'],x['Order Status'])[['PENDING']]
# Out:
# Order Status   PENDING
# Order City
# Agra                 7
# Ajmer               17
# Akola                0
# Aligarh              4
# Allahabad            0
# ...                ...
# Vadodara             1
# Varanasi             0
# Vijayawada           0
# Visakhapatnam       15
# Warangal             1
#
# [146 rows x 1 columns]

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Fname', 'Customer Id', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Department Id', 'Department Name',
#        'Latitude', 'Longitude', 'Market', 'Order City', 'Order Country',
#        'Order Customer Id', 'order date (DateOrders)', 'Order Id',
#        'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Order Region',
#        'Order State', 'Order Status', 'Product Card Id', 'Product Category Id',
#        'Product Name', 'Product Price', 'Product Status',
# ...

# %%
pd.crosstab(df['Order Country'],df['Order Status'])[['SUSPECTED_FRAUD']].sort_values('SUSPECTED_FRAUD')
# Out:
# Order Status    SUSPECTED_FRAUD
# Order Country
# Kirguistán                    0
# Moldavia                      0
# Mauritania                    0
# Mali                          0
# Macedonia                     0
# ...                         ...
# Australia                   197
# Alemania                    227
# México                      317
# Francia                     362
# Estados Unidos              573
#
# [164 rows x 1 columns]

# %%
df['Order Status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: Order Status, dtype: int64

# %%
y = df[df['Order Status']=='SUSPECTED_FRAUD']

# %%
y['Order Country'].value_counts()
# Out:
# Estados Unidos    573
# Francia           362
# México            317
# Alemania          227
# Australia         197
#                  ...
# Uzbekistán          1
# Grecia              1
# Bangladés           1
# Somalia             1
# Georgia             1
# Name: Order Country, Length: 102, dtype: int64

# %%
df.groupby(['Order Item Discount'])['Product Name'].value_counts()
# Out:
# Order Item Discount  Product Name
# 0.0                  Perfect Fitness Perfect Rip Deck             1363
#                      Nike Men's CJ Elite 2 TD Football Cleat      1235
#                      Nike Men's Dri-FIT Victory Golf Polo         1163
#                      O'Brien Men's Neoprene Life Vest             1054
#                      Field & Stream Sportsman 16 Gun Fire Safe     962
#                                                                   ...
# 340.0                SOLE E35 Elliptical                             1
# 360.0                SOLE E35 Elliptical                             1
# 375.0                Dell Laptop                                    25
# 400.0                SOLE E35 Elliptical                             1
# 500.0                SOLE E35 Elliptical                             1
# Name: Product Name, Length: 4174, dtype: int64

# %%
plt.figure(figsize=(80,95))
sns.barplot(data=df,x='Sales',y='Product Name')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Product Name'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Reading the CSV file

# %%
df = pd.read_csv('DataCoSupplyChainDataset (1).csv',encoding='ISO-8859-1')

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %% [markdown]
# Checking all columns

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %% [markdown]
# Droping unnecessary columns

# %%
df.drop(['Customer Email','Customer Password','Product Image'],axis=1,inplace=True)

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %% [markdown]
# Checking null values

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# Longitude                             0
# Market                                0
# ...

# %% [markdown]
# Droping columns with null values

# %%
df.drop(['Customer Lname','Order Zipcode','Product Description','Customer Zipcode'],axis=1,inplace=True)

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %% [markdown]
# Running condition and assigned as x variale for India to List all the cities and the respective number of pending orders in 'India' with crosstab function

# %%
x = df[df['Order Country']=='India']

# %%
x
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 13         DEBIT                         2                              1
# 14      TRANSFER                         2                              1
# 15         DEBIT                         2                              1
# ...          ...                       ...                            ...
# 180488   PAYMENT                         2                              4
# 180490  TRANSFER                         4                              4
# 180493     DEBIT                         2                              4
# 180494     DEBIT                         2                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
pd.crosstab(x['Order City'],x['Order Status'])[['PENDING']]
# Out:
# Order Status   PENDING
# Order City
# Agra                 7
# Ajmer               17
# Akola                0
# Aligarh              4
# Allahabad            0
# ...                ...
# Vadodara             1
# Varanasi             0
# Vijayawada           0
# Visakhapatnam       15
# Warangal             1
#
# [146 rows x 1 columns]

# %% [markdown]
# Running crosstab function again to find Which country has the most suspected fraud

# %%
pd.crosstab(df['Order Country'],df['Order Status'])[['SUSPECTED_FRAUD']].sort_values('SUSPECTED_FRAUD')
# Out:
# Order Status    SUSPECTED_FRAUD
# Order Country
# Kirguistán                    0
# Moldavia                      0
# Mauritania                    0
# Mali                          0
# Macedonia                     0
# ...                         ...
# Australia                   197
# Alemania                    227
# México                      317
# Francia                     362
# Estados Unidos              573
#
# [164 rows x 1 columns]

# %% [markdown]
# Checking for Order status w.r.t Value Counts function

# %%
df['Order Status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: Order Status, dtype: int64

# %% [markdown]
# Create a series object which only has SUSPECTED_FRAUD Column.

# %%
a = pd.Series(df['Order Status']=='SUSPECTED_FRAUD')

# %%
a
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 180514    False
# 180515    False
# 180516    False
# 180517    False
# 180518    False
# Name: Order Status, Length: 180519, dtype: bool

# %% [markdown]
# In order to check which country has the most suspected fraud we are applying a condition below first and running the values count funtion

# %%
y = df[df['Order Status']=='SUSPECTED_FRAUD']

# %%
y['Order Country'].value_counts()
# Out:
# Estados Unidos    573
# Francia           362
# México            317
# Alemania          227
# Australia         197
#                  ...
# Uzbekistán          1
# Grecia              1
# Bangladés           1
# Somalia             1
# Georgia             1
# Name: Order Country, Length: 102, dtype: int64

# %% [markdown]
# Applying group by function to check Which product(s) has/have the maximum discount

# %%
df.groupby(['Order Item Discount'])['Product Name'].value_counts()
# Out:
# Order Item Discount  Product Name
# 0.0                  Perfect Fitness Perfect Rip Deck             1363
#                      Nike Men's CJ Elite 2 TD Football Cleat      1235
#                      Nike Men's Dri-FIT Victory Golf Polo         1163
#                      O'Brien Men's Neoprene Life Vest             1054
#                      Field & Stream Sportsman 16 Gun Fire Safe     962
#                                                                   ...
# 340.0                SOLE E35 Elliptical                             1
# 360.0                SOLE E35 Elliptical                             1
# 375.0                Dell Laptop                                    25
# 400.0                SOLE E35 Elliptical                             1
# 500.0                SOLE E35 Elliptical                             1
# Name: Product Name, Length: 4174, dtype: int64

# %% [markdown]
# Which year had the minimum sales for "Nike" products

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df['Product Name'].value_counts()
# Out:
# Perfect Fitness Perfect Rip Deck                 24515
# Nike Men's CJ Elite 2 TD Football Cleat          22246
# Nike Men's Dri-FIT Victory Golf Polo             21035
# O'Brien Men's Neoprene Life Vest                 19298
# Field & Stream Sportsman 16 Gun Fire Safe        17325
#                                                  ...
# Stiga Master Series ST3100 Competition Indoor       27
# SOLE E35 Elliptical                                 15
# Bushnell Pro X7 Jolt Slope Rangefinder              11
# Bowflex SelectTech 1090 Dumbbells                   10
# SOLE E25 Elliptical                                 10
# Name: Product Name, Length: 118, dtype: int64

# %%
df['nike1'] = df['Product Name'].str.split(' ').str[0].where(df['Product Name'].str.contains('Nike'),0)

# %%
df.nike1
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 180514    0
# 180515    0
# 180516    0
# 180517    0
# 180518    0
# Name: nike1, Length: 180519, dtype: object

# %%
df.nike1.value_counts()
# Out:
# 0       123210
# Nike     57309
# Name: nike1, dtype: int64

# %%
df_nike1 = df[df['nike1']=='Nike']

# %%
df_nike1
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 50       PAYMENT                         6                              2
# 52       PAYMENT                         3                              2
# 53       PAYMENT                         5                              2
# 54       PAYMENT                         6                              2
# 59       PAYMENT                         2                              2
# ...          ...                       ...                            ...
# 179604  TRANSFER                         5                              4
# 179605  TRANSFER                         2                              4
# 179606  TRANSFER                         3                              4
# 179607  TRANSFER                         5                              4
# 179608  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df['order date (DateOrders)']
# Out:
# 0         1/31/2018 22:56
# 1         1/13/2018 12:27
# 2         1/13/2018 12:06
# 3         1/13/2018 11:45
# 4         1/13/2018 11:24
#                ...
# 180514     1/16/2016 3:40
# 180515     1/16/2016 1:34
# 180516    1/15/2016 21:00
# 180517    1/15/2016 20:18
# 180518    1/15/2016 18:54
# Name: order date (DateOrders), Length: 180519, dtype: object

# %%
df['Year'] = df['order date (DateOrders)'].str.split('/').str[-1].str.split(' ').str[0]

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
sns.barplot(x=df.Year,y=df.Sales,data=df.nike1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %% [markdown]
#  Visualize sales of different company Products

# %%
plt.figure(figsize=(80,95))
sns.barplot(data=df,x='Sales',y='Product Name')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Product Name'>
